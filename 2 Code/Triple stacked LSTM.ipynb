# %% [markdown]
# #Input song

# %%
# Input song name here
song_name = 'burg_spinnerlied.mid'

# %% [markdown]
# #Setup

# %% [markdown]
# ###Setup Google drive authentication

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
import os
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Download the files from google drive to colab cloud

# %% [markdown]
# ###Import midi

# %%
# choose a local (colab) directory to store the data.
local_download_path = os.path.expanduser('./midi/')
try:
  os.makedirs(local_download_path)
except: pass

# 2. Auto-iterate using the query syntax
#    https://developers.google.com/drive/v2/web/search-parameters
file_list = drive.ListFile(
    {'q': "'1M86xzpCMVN9yi-BW4heLa3g5O2d90zOe' in parents"}).GetList()

for f in file_list:
  if f['title'] == '__pycache__':
    continue
  # 3. Create & download by id.
  print('title: %s, id: %s' % (f['title'], f['id']))
  fname = os.path.join(local_download_path, f['title'])
  print('downloading to {}'.format(fname))
  f_ = drive.CreateFile({'id': f['id']})
  f_.GetContentFile(fname)
# Out:
# title: containers.py, id: 1c7dcHnHRhU1ZKKMpJlSigrPj27oqreTj
# downloading to ./midi/containers.py
# title: __init__.py, id: 12GL5ClgPsNQNdN7JidPU42HrwGL49td4
# downloading to ./midi/__init__.py
# title: constants.py, id: 1PrLV_I5S9Rl0XMyCqNiNUjIA3QUwWo1q
# downloading to ./midi/constants.py
# title: events.py, id: 1odPgLuxaIj_OKIxAZ5jeFOiVCb_QaQE_
# downloading to ./midi/events.py
# title: fileio.py, id: 1X9Xhyi_Mb4_mbmtGBGrYwgSs1PeT1hVW
# downloading to ./midi/fileio.py
# title: util.py, id: 1eGk0yqJrD5IqHwLq79wcHVjB8fNjhT34
# downloading to ./midi/util.py

# %% [markdown]
# ###Download songs

# %%
# choose a local (colab) directory to store the data.
local_download_path = os.path.expanduser('./songs/')
try:
  os.makedirs(local_download_path)
except: pass

# 2. Auto-iterate using the query syntax
#    https://developers.google.com/drive/v2/web/search-parameters
file_list = drive.ListFile(
    {'q': "'1OVkRPSKy9URYXZgJn-2pyk7fwO6di7wp' in parents"}).GetList()

for f in file_list:
  if f['title'] == '__pycache__':
    continue
  # 3. Create & download by id.
  print('title: %s, id: %s' % (f['title'], f['id']))
  fname = os.path.join(local_download_path, f['title'])
  print('downloading to {}'.format(fname))
  f_ = drive.CreateFile({'id': f['id']})
  f_.GetContentFile(fname)
# Out:
# title: Tempestat.mid, id: 1g64y4NNuCnwcq2npZyCjydnUIj_krEH-
# downloading to ./songs/Tempestat.mid
# title: mz_331_3.mid, id: 1O1B7U2TIpvSDK9Vrwd_jJ4t-mTYDZQQE
# downloading to ./songs/mz_331_3.mid
# title: burg_gewitter.mid, id: 19VamEsN9QnrpJwJD7iuv2BsL09lTpKfN
# downloading to ./songs/burg_gewitter.mid
# title: Pathetique.mid, id: 1jUwBGd5yxBn-7gy9aCqC30zFi74mr_V-
# downloading to ./songs/Pathetique.mid
# title: mond_1.mid, id: 1YebxGdVcGpYNX2ddwgekfJNhfjZp0Oci
# downloading to ./songs/mond_1.mid
# title: clementi_opus36_1_1.mid, id: 15_CljB-SiUjdXQ87u9rjFMTdV8nDifQN
# downloading to ./songs/clementi_opus36_1_1.mid
# title: chpn_op10_e05.mid, id: 1JFnKiQs96_UvSNc9bVABAlEyIb-I8oml
# downloading to ./songs/chpn_op10_e05.mid
# title: mozart_shenko.mid, id: 1_NkIxFsIuRbBzwLRCzppsZD0vYJTTcJr
# downloading to ./songs/mozart_shenko.mid
# title: schubert_D850_4.mid, id: 1_1ngL4NFwWgboHD4XExfiOIEfcb6qGQi
# downloading to ./songs/schubert_D850_4.mid
# title: burg_spinnerlied.mid, id: 15m8QFQ_90nhyyHFxrM-tzLzxAvJLFjY-
# downloading to ./songs/burg_spinnerlied.mid
# title: Piano Sonata n15 K593-494.mid, id: 1Bq0h-Rdep69nULxUO41_UsiDPjEwUxXK
# downloading to ./songs/Piano Sonata n15 K593-494.mid
# title: rac_op23_5.mid, id: 1gXaAEWZT0Q1tifUh50EZQH201Jy8bLCv
# downloading to ./songs/rac_op23_5.mid
# title: bach_850.mid, id: 1f18_4PwijBD4Jb_t156dlE3PuSaaRqDx
# downloading to ./songs/bach_850.mid
# title: Piano_Sonata_n24.mid, id: 1Qzi8MGFkCCwBtksSKgxS85d-0PABGGjm
# downloading to ./songs/Piano_Sonata_n24.mid
# title: deb_clai.mid, id: 1i53nN2slt1uu8FIrmfpV9TmO_UaMw-ns
# downloading to ./songs/deb_clai.mid
# title: chpn_op25_e2.mid, id: 1SoTyPxMxBUCBR2ffWdWcTf03UoFAydwB
# downloading to ./songs/chpn_op25_e2.mid
# title: fruehlingsrauschen.mid, id: 1WMKw1DfIKlGrdiQczWrDS-f4rZ0vyINp
# downloading to ./songs/fruehlingsrauschen.mid
# title: burg_quelle.mid, id: 10Fj3G3zLnGKvE7sx3_ESFswfNOpk41ZV
# downloading to ./songs/burg_quelle.mid
# title: schub_d960_4.mid, id: 12UD3uls3-NKa3ulKVsvdRksHc7WrSfqr
# downloading to ./songs/schub_d960_4.mid
# title: Moonlight.mid, id: 1SCat2W1B8bSakQP31kZkB3Tl9mZ9hZnx
# downloading to ./songs/Moonlight.mid

# %% [markdown]
# ###Download models

# %%
# choose a local (colab) directory to store the data.
local_download_path = os.path.expanduser('./models/')
try:
  os.makedirs(local_download_path)
except: pass

# 2. Auto-iterate using the query syntax
#    https://developers.google.com/drive/v2/web/search-parameters
file_list = drive.ListFile(
    {'q': "'1E1c1Pb3BHgmTJYL5GhfRtZfFsU4MNPay' in parents"}).GetList()

for f in file_list:
  if f['title'] == '__pycache__':
    continue
  # 3. Create & download by id.
  print('title: %s, id: %s' % (f['title'], f['id']))
  fname = os.path.join(local_download_path, f['title'])
  print('downloading to {}'.format(fname))
  f_ = drive.CreateFile({'id': f['id']})
  f_.GetContentFile(fname)
# Out:
# title: schub_d960_4.midmodel.chkpt.data-00000-of-00001(1), id: 1-2zBeHBdnKnrcPtQdooCSu7qvaT9hRTl
# downloading to ./models/schub_d960_4.midmodel.chkpt.data-00000-of-00001(1)
# title: bach_850.midmodel.chkpt.meta, id: 1d2JC2leZRs7TRczkt6huP1Lf3LAHt378
# downloading to ./models/bach_850.midmodel.chkpt.meta
# title: Pathetique.midmodel.chkpt.data-00000-of-00001, id: 1r6txcVD09c6gOh6GbcPgrc4WBE3OUAX-
# downloading to ./models/Pathetique.midmodel.chkpt.data-00000-of-00001
# title: mz_331_3.midmodel.chkpt.data-00000-of-00001, id: 12QaqrA_qRRLx1U96j2HZSlvEo_2yxSI9
# downloading to ./models/mz_331_3.midmodel.chkpt.data-00000-of-00001
# title: schubert_D850_4.midmodel.chkpt.data-00000-of-00001, id: 1f3rXJ5QEIzZ21EmYJSPlUBXXE6JxQtGg
# downloading to ./models/schubert_D850_4.midmodel.chkpt.data-00000-of-00001
# title: mz_331_3.midmodel.chkpt.meta, id: 1IVDx6LE5uakjGynTEvwzpU_h_1hiVUjs
# downloading to ./models/mz_331_3.midmodel.chkpt.meta
# title: Piano_Sonata_n24.midmodel.chkpt.meta, id: 1uA79NAIqsSlLzAOLyZqTHSXTlBj5ifMN
# downloading to ./models/Piano_Sonata_n24.midmodel.chkpt.meta
# title: chpn_op10_e05.midmodel.chkpt.data-00000-of-00001, id: 1jwyptgods-CMX5hMTEG80uG0j7eiOPQu
# downloading to ./models/chpn_op10_e05.midmodel.chkpt.data-00000-of-00001
# title: burg_spinnerlied.midmodel.chkpt.data-00000-of-00001, id: 1fXcWp5dVgI2NJ8v4DbH7-Zv3muz7oQG_
# downloading to ./models/burg_spinnerlied.midmodel.chkpt.data-00000-of-00001
# title: Piano Sonata n15 K593-494.midmodel.chkpt.data-00000-of-00001, id: 1BAjbb9lvO1IgTIuZfokLoiNClc_JqTjl
# downloading to ./models/Piano Sonata n15 K593-494.midmodel.chkpt.data-00000-of-00001
# title: burg_spinnerlied.midmodel.chkpt(1).meta, id: 1Ksk01AncR_hf5-5SYIaL2TlzAPaZFHRo
# downloading to ./models/burg_spinnerlied.midmodel.chkpt(1).meta
# title: chpn_op10_e05.midmodel.chkpt.meta, id: 1bXhPDFWTk-UbTw7zkCORVzY4ks0LQ6s1
# downloading to ./models/chpn_op10_e05.midmodel.chkpt.meta
# title: clementi_opus36_1_1.midmodel.chkpt.meta, id: 1f7DjhI3CB38Z_lc9c3Dtnzd768UgRAKI
# downloading to ./models/clementi_opus36_1_1.midmodel.chkpt.meta
# title: schubert_D850_4.midmodel.chkpt.meta, id: 1hrGnKc9GgslO_hmwEuDKAH6X4NHdiejN
# downloading to ./models/schubert_D850_4.midmodel.chkpt.meta
# title: Moonlight.midmodel.chkpt.meta, id: 1DnYAkDhEkogPYomyLUv70QNKIYnYboUG
# downloading to ./models/Moonlight.midmodel.chkpt.meta
# title: Tempestat.midmodel.chkpt.meta, id: 1wIGjJi5gGNBZBCabstLxBpkBSGdy5Wgv
# downloading to ./models/Tempestat.midmodel.chkpt.meta
# title: fruehlingsrauschen.midmodel.chkpt.meta, id: 1EqAOjIgR695hiv3T4ij92g-fxNvV0cDE
# downloading to ./models/fruehlingsrauschen.midmodel.chkpt.meta
# title: mond_1.midmodel.chkpt.meta, id: 1b4MvAD-tye5ktWk-DIkD2uBimQGt6tP9
# downloading to ./models/mond_1.midmodel.chkpt.meta
# title: chpn_op25_e2.midmodel.chkpt.meta, id: 19ddB_yKXPk8tn33awzXE9la1L6_PWGvS
# downloading to ./models/chpn_op25_e2.midmodel.chkpt.meta
# title: chpn_op25_e2.midmodel.chkpt.data-00000-of-00001, id: 1VrX0Dc7ft6dS5gsRQiDyX3s74nrMxTI_
# downloading to ./models/chpn_op25_e2.midmodel.chkpt.data-00000-of-00001
# title: burg_gewitter.midmodel.chkpt.meta, id: 1ek3fkTOn17bOxWRdNr0missfwZsBtJ_x
# downloading to ./models/burg_gewitter.midmodel.chkpt.meta
# title: rac_op23_5.midmodel.chkpt.meta, id: 1HtP0hbdy8FGZiGI1zWCRzhfaxhCwABMw
# downloading to ./models/rac_op23_5.midmodel.chkpt.meta
# title: schub_d960_4.midmodel.chkpt(1).meta, id: 1tgc48sayiKsdyd1HdVhL9L9Eor4Hwux7
# downloading to ./models/schub_d960_4.midmodel.chkpt(1).meta
# title: mozart_shenko.midmodel.chkpt.meta, id: 1DTuC6d0bcALXJU9XQdM60tYqK54CHnoS
# downloading to ./models/mozart_shenko.midmodel.chkpt.meta
# title: burg_gewitter.midmodel.chkpt.data-00000-of-00001, id: 1NZA6KY9zSwgzQjI3dnFVQYkBlYY6_MyJ
# downloading to ./models/burg_gewitter.midmodel.chkpt.data-00000-of-00001
# title: bach_850.midmodel.chkpt.data-00000-of-00001, id: 1v8j6Cii_tjyEQgjZ4wZBJ25T3Tw7-1Zb
# downloading to ./models/bach_850.midmodel.chkpt.data-00000-of-00001
# title: burg_spinnerlied.midmodel.chkpt.data-00000-of-00001(1), id: 1ur5pH3Cnx4jP4Po1qkvKFIKN3OlLKIKV
# downloading to ./models/burg_spinnerlied.midmodel.chkpt.data-00000-of-00001(1)
# title: mozart_shenko.midmodel.chkpt.data-00000-of-00001, id: 1G51-mrGdNHZZKfjGI_GU5y4ToPUbKw2h
# downloading to ./models/mozart_shenko.midmodel.chkpt.data-00000-of-00001
# title: rac_op23_5.midmodel.chkpt.data-00000-of-00001, id: 1aVSE0_b6YJxgOSWxxmAiYJWo9Xl-Szbo
# downloading to ./models/rac_op23_5.midmodel.chkpt.data-00000-of-00001
# title: Moonlight.midmodel.chkpt.data-00000-of-00001, id: 13S0GkLk6Us1sIx71rUiaDNtwhDB1Lj5S
# downloading to ./models/Moonlight.midmodel.chkpt.data-00000-of-00001
# title: Tempestat.midmodel.chkpt.data-00000-of-00001, id: 1Q82kCzTo82OkOMlaL3HEa0V72qxf9afm
# downloading to ./models/Tempestat.midmodel.chkpt.data-00000-of-00001
# title: schub_d960_4.midmodel.chkpt.meta, id: 1eyF-YiLNuiZnTfaP2oacEfqSaaM7RPG8
# downloading to ./models/schub_d960_4.midmodel.chkpt.meta
# title: burg_spinnerlied.midmodel.chkpt.meta, id: 14KQf0d3PEb17qeyrocJk8AI8xg9_G4Td
# downloading to ./models/burg_spinnerlied.midmodel.chkpt.meta
# title: mond_1.midmodel.chkpt.data-00000-of-00001, id: 1aJdO7NWn9TLHVruz_VLOIG_0xFg-o9k_
# downloading to ./models/mond_1.midmodel.chkpt.data-00000-of-00001
# title: Piano Sonata n15 K593-494.midmodel.chkpt.meta, id: 1aL44Ud2hl4xIH8de2L0kNz1HauT562_-
# downloading to ./models/Piano Sonata n15 K593-494.midmodel.chkpt.meta
# title: clementi_opus36_1_1.midmodel.chkpt.data-00000-of-00001, id: 1qC918hAR028VCLHR83pHQm20rvCdM2sz
# downloading to ./models/clementi_opus36_1_1.midmodel.chkpt.data-00000-of-00001
# title: Piano_Sonata_n24.midmodel.chkpt.data-00000-of-00001, id: 1A_f8BaFQtJYiWK-9PZa1nMMgCg-fqhg0
# downloading to ./models/Piano_Sonata_n24.midmodel.chkpt.data-00000-of-00001
# title: fruehlingsrauschen.midmodel.chkpt.data-00000-of-00001, id: 1CmpGHzBjozw3ODvFITW62fyZxBLREaq1
# downloading to ./models/fruehlingsrauschen.midmodel.chkpt.data-00000-of-00001
# title: Pathetique.midmodel.chkpt.meta, id: 1hwbLrl49bGzVaX_6ymVMdC-NCO9dMLVG
# downloading to ./models/Pathetique.midmodel.chkpt.meta
# title: schub_d960_4.midmodel.chkpt.data-00000-of-00001, id: 1blMylp7P-GvYnic_sVZhOecMXoty7DhV
# downloading to ./models/schub_d960_4.midmodel.chkpt.data-00000-of-00001
# title: chpn_op25_e2.midmodel.chkpt.index, id: 1LIlYzC3C9mw5eq0Sya5QO3s3Y85Q41G4
# downloading to ./models/chpn_op25_e2.midmodel.chkpt.index
# title: Piano_Sonata_n24.midmodel.chkpt.index, id: 1S9-qlNE73Uc7W0dIf77ekaEZ71_kpgN3
# downloading to ./models/Piano_Sonata_n24.midmodel.chkpt.index
# title: chpn_op10_e05.midmodel.chkpt.index, id: 1FsW6Rk4bP3FS2TqbXGd9jZm3vNEJ7iv9
# downloading to ./models/chpn_op10_e05.midmodel.chkpt.index
# title: Tempestat.midmodel.chkpt.index, id: 1JoL8ChZZu0TTWu-SsINZwhuVQ2DTYMzQ
# downloading to ./models/Tempestat.midmodel.chkpt.index
# title: Pathetique.midmodel.chkpt.index, id: 1m8MMqwOuPs8LxNUWd9QWbF7L4Im1U-pj
# downloading to ./models/Pathetique.midmodel.chkpt.index
# title: burg_spinnerlied.midmodel.chkpt.index, id: 1szzS705UuJcsf-h-xtLn1KyFCPl-dcx3
# downloading to ./models/burg_spinnerlied.midmodel.chkpt.index
# title: fruehlingsrauschen.midmodel.chkpt.index, id: 1JYgFKtjF95EZrSMjXH64b-cH7zlu98ZO
# downloading to ./models/fruehlingsrauschen.midmodel.chkpt.index
# title: mozart_shenko.midmodel.chkpt.index, id: 1QMM9hF_qVL9Vm1UOkqYdEc3HKSrBZHvx
# downloading to ./models/mozart_shenko.midmodel.chkpt.index
# title: burg_gewitter.midmodel.chkpt.index, id: 1wihd3bq1_aqwNrKgSHStgBR1WNwvFDIH
# downloading to ./models/burg_gewitter.midmodel.chkpt.index
# title: schubert_D850_4.midmodel.chkpt.index, id: 1cz6vlABClAnkPKBoeMEt6iZHKqvAGKu9
# downloading to ./models/schubert_D850_4.midmodel.chkpt.index
# title: schub_d960_4.midmodel.chkpt(1).index, id: 1wOH-8Ua4an95rS0vSGIkmFdL9Z4IWsZx
# downloading to ./models/schub_d960_4.midmodel.chkpt(1).index
# title: Piano Sonata n15 K593-494.midmodel.chkpt.index, id: 1apNyPpmxTbK5GYv6GbYGisAweZ_ASsyy
# downloading to ./models/Piano Sonata n15 K593-494.midmodel.chkpt.index
# title: Moonlight.midmodel.chkpt.index, id: 1plEpHSM1XB5ykD5F2mJei2a5-A4X1DS3
# downloading to ./models/Moonlight.midmodel.chkpt.index
# title: schub_d960_4.midmodel.chkpt.index, id: 1mCYXHDBTNpZ41rriJgYWkpJocqg1Jaft
# downloading to ./models/schub_d960_4.midmodel.chkpt.index
# title: rac_op23_5.midmodel.chkpt.index, id: 1JT_b-nzhEwtnxNfrdMqAEjUNFk20ltLI
# downloading to ./models/rac_op23_5.midmodel.chkpt.index
# title: mz_331_3.midmodel.chkpt.index, id: 16KlUof0oj-uqHj3EeBhcVyxCnrpY6iDo
# downloading to ./models/mz_331_3.midmodel.chkpt.index
# title: mond_1.midmodel.chkpt.index, id: 13pqyYL9x_tllEPAMd1zp24P4B4phHXED
# downloading to ./models/mond_1.midmodel.chkpt.index
# title: clementi_opus36_1_1.midmodel.chkpt.index, id: 1Rafdw2YCnCukzRXKta-qPG7C-LgxpOJU
# downloading to ./models/clementi_opus36_1_1.midmodel.chkpt.index
# title: bach_850.midmodel.chkpt.index, id: 1S9TmbyvcCcVHzi0ufpYTANJBf-T9JKuK
# downloading to ./models/bach_850.midmodel.chkpt.index
# title: burg_spinnerlied.midmodel.chkpt(1).index, id: 1baMFWZ5hupHDwRTUho-5iq5kAHdDadja
# downloading to ./models/burg_spinnerlied.midmodel.chkpt(1).index

# %% [markdown]
# ##Import packages

# %%
import warnings
warnings.simplefilter("ignore")

# %%
from __future__ import print_function
import IPython
import sys
import numpy as np
import tensorflow as tf
from tensorflow.contrib import rnn
import midi
import subprocess
# %tensorflow_version 1.x
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# #Functions for parsing midi files

# %% [markdown]
# ##Define bounds

# %%
lowerBound = 21
upperBound = 108
span = upperBound-lowerBound

# %% [markdown]
# ##Function for note matrix to Midi file

# %%
def noteStateMatrixToMidi(statematrix, name="example", span=span):
    statematrix = np.array(statematrix)
    if not len(statematrix.shape) == 3:
        statematrix = np.dstack((statematrix[:, :span], statematrix[:, span:]))
    statematrix = np.asarray(statematrix)
    pattern = midi.Pattern()
    track = midi.Track()
    pattern.append(track)
    
    span = upperBound-lowerBound
    tickscale = 45
    
    lastcmdtime = 0
    prevstate = [[0,0] for x in range(span)]
    for time, state in enumerate(statematrix + [prevstate[:]]):  
        offNotes = []
        onNotes = []
        for i in range(span):
            n = state[i]
            p = prevstate[i]
            if p[0] == 1:
                if n[0] == 0:
                    offNotes.append(i)
                elif n[1] == 1:
                    offNotes.append(i)
                    onNotes.append(i)
            elif n[0] == 1:
                onNotes.append(i)
        for note in offNotes:
            track.append(midi.NoteOffEvent(tick=(time-lastcmdtime)*tickscale, pitch=note+lowerBound))
            lastcmdtime = time
        for note in onNotes:
            track.append(midi.NoteOnEvent(tick=(time-lastcmdtime)*tickscale, velocity=40, pitch=note+lowerBound))
            lastcmdtime = time
            
        prevstate = state
    
    eot = midi.EndOfTrackEvent(tick=1)
    track.append(eot)

    midi.write_midifile("{}.midi".format(name), pattern)

# %% [markdown]
# ##Function for midi file to note matrix

# %%
def midiToNoteStateMatrix(midifile, squash=True, span=span):
    pattern = midi.read_midifile(midifile)
    timeleft = [track[0].tick for track in pattern]
    posns = [0 for track in pattern]

    statematrix = []
    time = 0

    state = [[0,0] for x in range(span)]
    statematrix.append(state)
    condition = True
    while condition:
        if time % (pattern.resolution / 4) == (pattern.resolution / 8):
            # Crossed a note boundary. Create a new state, defaulting to holding notes
            oldstate = state
            state = [[oldstate[x][0],0] for x in range(span)]
            statematrix.append(state)
        
        for i in range(len(timeleft)): #For each track
            if not condition:
                break
            while timeleft[i] == 0:
                track = pattern[i]
                pos = posns[i]

                evt = track[pos]
                if isinstance(evt, midi.NoteEvent):
                    if (evt.pitch < lowerBound) or (evt.pitch >= upperBound):
                        pass
#                         print("Note {} at time {} out of bounds (ignoring)".format(evt.pitch, time))
                    else:
                        if isinstance(evt, midi.NoteOffEvent) or evt.velocity == 0:
                            state[evt.pitch-lowerBound] = [0, 0]
                        else:
                            state[evt.pitch-lowerBound] = [1, 1]
                elif isinstance(evt, midi.TimeSignatureEvent):
                    if evt.numerator not in (2, 4):
                        # We don't want to worry about non-4 time signatures. Bail early!
                        # print "Found time signature event {}. Bailing!".format(evt)
                        out =  statematrix
                        condition = False
                        break
                try:
                    timeleft[i] = track[pos + 1].tick
                    posns[i] += 1
                except IndexError:
                    timeleft[i] = None

            if timeleft[i] is not None:
                timeleft[i] -= 1

        if all(t is None for t in timeleft):
            break

        time += 1

    S = np.array(statematrix)
    statematrix = np.hstack((S[:, :, 0], S[:, :, 1]))
    statematrix = np.asarray(statematrix).tolist()
    return statematrix

# %% [markdown]
# #Parse midi

# %%
input_ = midiToNoteStateMatrix('./songs/' + song_name)
input_ = np.array(input_)
print(input_.shape)

X_train_list = []
length = 110
for i in range(input_.shape[0] - length):
    X_train_list.append(input_[i:length+i])
X_train_org = np.array(X_train_list)
X_train_org = X_train_org[:3000, :,:]
print(X_train_org.shape)
X_train = X_train_org
# Out:
# (657, 174)
# (547, 110, 174)

# %%
# Convert to list
encoded_snippets = [X_train[i,:,:] for i in range(X_train.shape[0])]

# %%
NUM_SONGS = len(encoded_snippets)
print(str(NUM_SONGS) + " total snippets to learn from")
# Out:
# 547 total snippets to learn from

# %% [markdown]
# #Model Architecture

# %% [markdown]
# ##Define hyperparameters

# %%
input_size       = encoded_snippets[0].shape[1]   # The number of possible MIDI Notes
output_size      = input_size                  # Same as input size
hidden_size      = 128                         # Number of neurons in hidden layer

learning_rate    = 0.01 # Learning rate of the model
training_steps   = 2000  # Number of epochs during training
timesteps        = 100    # Length of song snippet -- this is what is fed into the model

# %% [markdown]
# ##Define placeholders

# %%
tf.reset_default_graph()

input_placeholder_shape = [None, timesteps, input_size] 
output_placeholder_shape = [None, output_size] 

input_vec  = tf.placeholder("float", input_placeholder_shape)  
output_vec = tf.placeholder("float", output_placeholder_shape)

# %% [markdown]
# ##Initialize weights

# %%
# Initialize weights
weights = tf.Variable(tf.random_normal([hidden_size, output_size])) 
biases = tf.Variable(tf.random_normal([output_size]))

# %% [markdown]
# ##Define RNN Cell - Triple stacked LSTM

# %%
def RNN(input_vec, weights, biases):
    
    input_vec = tf.unstack(input_vec, timesteps, 1)

    cell1 = tf.nn.rnn_cell.BasicLSTMCell(hidden_size, forget_bias=1.0, state_is_tuple=True)
    cell2 = tf.nn.rnn_cell.BasicLSTMCell(hidden_size, forget_bias=1.0, state_is_tuple=True)
    cell3 = tf.nn.rnn_cell.BasicLSTMCell(hidden_size, forget_bias=1.0, state_is_tuple=True)

    stacked_cell = tf.nn.rnn_cell.MultiRNNCell([cell1, cell2, cell3], state_is_tuple=True)

    outputs, states = rnn.static_rnn(stacked_cell, input_vec, dtype=tf.float32)
    
    recurrent_net = (tf.matmul(outputs[-1], weights) + biases)
    
    prediction = tf.nn.sigmoid(recurrent_net)
    
    return recurrent_net, prediction

# %% [markdown]
# ##Define loss

# %%
warnings.simplefilter("ignore")
# logits and prediction
logits, prediction = RNN(input_vec, weights, biases)

# LOSS OPERATION:
loss_op = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
    logits=logits, labels=output_vec))
# Out:
# WARNING:tensorflow:From <ipython-input-17-a1131e258dae>:5: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-17-a1131e258dae>:9: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-17-a1131e258dae>:11: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:735: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# ##Define optimizer

# %%
# TRAINING OPERATION:
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# %% [markdown]
# ##Define accuracy measurement logic

# %%
# ACCURACY: We compute the accuracy in three steps.

# make notes 1 if prob > 0.3
pred_notes = tf.cast(tf.greater_equal(prediction, 0.3), tf.float32)

# take 'AND' condition for equality with actual note to be played - this makes sure all the notes are correct
correct_pred = tf.reduce_all(tf.equal(output_vec, pred_notes), 1)

# take mean of correctly predicted notes - gives % correct notes played
accuracy_op = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %% [markdown]
# #Model training

# %% [markdown]
# ##Initialize variables

# %%
init = tf.global_variables_initializer()

# %% [markdown]
# ##Launch and run the session

# %%
# 1) Launch the session
sess = tf.InteractiveSession()

# 2) Initialize the variables
sess.run(init)

# 3) Train!
display_step = 10 # how often to display progress
for step in range(training_steps):
    
    batch_x = X_train[:,:timesteps,:]
    batch_y = X_train[:,timesteps,:]

    # TRAINING: run the training operation with a feed_dict to fill in the placeholders
    '''TODO: Feed the training batch into the feed_dict.'''
    feed_dict = {
                    input_vec: batch_x,
                    output_vec: batch_y
                }
    sess.run(train_op, feed_dict=feed_dict)
    
    # DISPLAY METRICS
    if step % display_step == 0 or step == 1:
        # LOSS, ACCURACY: Compute the loss and accuracy by running both operations 
        loss, acc = sess.run([loss_op, accuracy_op], feed_dict=feed_dict)     
        suffix = "\nStep " + str(step) + ", Loss= " + \
                 "{:.4f}".format(loss) + ", Training Accuracy= " + \
                 "{:.3f}".format(acc)
        if acc >= 0.995:
          break
        print(suffix)
# Out:
# Step 0, Loss= 0.8070, Training Accuracy= 0.000
#
# Step 1, Loss= 1.3608, Training Accuracy= 0.000
#
# Step 10, Loss= 0.1636, Training Accuracy= 0.000
#
# Step 20, Loss= 0.1411, Training Accuracy= 0.020
#
# Step 30, Loss= 0.1370, Training Accuracy= 0.138
#
# Step 40, Loss= 0.1348, Training Accuracy= 0.054
#
# Step 50, Loss= 0.1325, Training Accuracy= 0.097
#
# Step 60, Loss= 0.1295, Training Accuracy= 0.056
#
# Step 70, Loss= 0.1257, Training Accuracy= 0.033
#
# Step 80, Loss= 0.1223, Training Accuracy= 0.006
#
# Step 90, Loss= 0.1185, Training Accuracy= 0.010
#
# Step 100, Loss= 0.1143, Training Accuracy= 0.006
#
# Step 110, Loss= 0.1114, Training Accuracy= 0.011
#
# Step 120, Loss= 0.1070, Training Accuracy= 0.021
#
# Step 130, Loss= 0.1037, Training Accuracy= 0.015
#
# Step 140, Loss= 0.0999, Training Accuracy= 0.020
#
# Step 150, Loss= 0.0973, Training Accuracy= 0.022
#
# Step 160, Loss= 0.0930, Training Accuracy= 0.035
#
# Step 170, Loss= 0.0894, Training Accuracy= 0.047
#
# Step 180, Loss= 0.0857, Training Accuracy= 0.041
#
# Step 190, Loss= 0.0826, Training Accuracy= 0.041
#
# Step 200, Loss= 0.0766, Training Accuracy= 0.060
#
# Step 210, Loss= 0.0750, Training Accuracy= 0.044
#
# Step 220, Loss= 0.0697, Training Accuracy= 0.081
#
# Step 230, Loss= 0.0657, Training Accuracy= 0.106
#
# Step 240, Loss= 0.0601, Training Accuracy= 0.127
#
# Step 250, Loss= 0.0656, Training Accuracy= 0.074
#
# Step 260, Loss= 0.0568, Training Accuracy= 0.116
#
# Step 270, Loss= 0.0508, Training Accuracy= 0.169
#
# Step 280, Loss= 0.0460, Training Accuracy= 0.210
#
# Step 290, Loss= 0.0532, Training Accuracy= 0.168
#
# Step 300, Loss= 0.0408, Training Accuracy= 0.271
#
# Step 310, Loss= 0.0362, Training Accuracy= 0.306
#
# Step 320, Loss= 0.0327, Training Accuracy= 0.350
#
# Step 330, Loss= 0.0297, Training Accuracy= 0.409
#
# Step 340, Loss= 0.0304, Training Accuracy= 0.357
#
# Step 350, Loss= 0.0254, Training Accuracy= 0.451
#
# Step 360, Loss= 0.0226, Training Accuracy= 0.506
#
# Step 370, Loss= 0.0202, Training Accuracy= 0.565
#
# Step 380, Loss= 0.0208, Training Accuracy= 0.583
#
# Step 390, Loss= 0.0176, Training Accuracy= 0.610
#
# Step 400, Loss= 0.0152, Training Accuracy= 0.671
#
# Step 410, Loss= 0.0137, Training Accuracy= 0.718
#
# Step 420, Loss= 0.0129, Training Accuracy= 0.718
#
# Step 430, Loss= 0.0111, Training Accuracy= 0.797
#
# Step 440, Loss= 0.0102, Training Accuracy= 0.826
#
# Step 450, Loss= 0.0093, Training Accuracy= 0.844
#
# Step 460, Loss= 0.0083, Training Accuracy= 0.862
#
# Step 470, Loss= 0.0075, Training Accuracy= 0.891
#
# Step 480, Loss= 0.0285, Training Accuracy= 0.333
#
# Step 490, Loss= 0.0178, Training Accuracy= 0.444
#
# Step 500, Loss= 0.0112, Training Accuracy= 0.698
#
# Step 510, Loss= 0.0083, Training Accuracy= 0.845
#
# Step 520, Loss= 0.0068, Training Accuracy= 0.897
#
# Step 530, Loss= 0.0059, Training Accuracy= 0.930
#
# Step 540, Loss= 0.0052, Training Accuracy= 0.956
#
# Step 550, Loss= 0.0048, Training Accuracy= 0.963
#
# Step 560, Loss= 0.0044, Training Accuracy= 0.971
#
# Step 570, Loss= 0.0041, Training Accuracy= 0.981
#
# Step 580, Loss= 0.0038, Training Accuracy= 0.986
#
# Step 590, Loss= 0.0035, Training Accuracy= 0.991
#
# Step 600, Loss= 0.0033, Training Accuracy= 0.993
#
# Step 610, Loss= 0.0031, Training Accuracy= 0.994
#
# Step 620, Loss= 0.0029, Training Accuracy= 0.994
#
# Step 630, Loss= 0.0028, Training Accuracy= 0.994
#
# Step 640, Loss= 0.0026, Training Accuracy= 0.994

# %% [markdown]
# #Save model

# %%
model_checkpoint = song_name + 'model.chkpt'
tf_saver = tf.train.Saver(tf.all_variables())
tf_saver.save(sess, model_checkpoint)

output = subprocess.check_output("ls | grep " + song_name + 'model.chkpt', shell=True)
file_names = output.decode("utf-8").split('\n') 

# save to drive
link = 'https://drive.google.com/open?id=1E1c1Pb3BHgmTJYL5GhfRtZfFsU4MNPay'
_, id = link.split("=")

for filename in file_names[:-1]:
  # get the folder id where you want to save your file
  file = drive.CreateFile({'parents':[{u'id': id}]})
  file.SetContentFile(filename)
  file.Upload()

# %% [markdown]
# #Load model

# %%
model_checkpoint = './models/' + song_name + 'model.chkpt'
sess = tf.InteractiveSession()
tf_saver = tf.train.Saver()
tf_saver.restore(sess, model_checkpoint)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/burg_spinnerlied.midmodel.chkpt

# %% [markdown]
# #Generate song

# %% [markdown]
# ##Input length of song to generate

# %%
# input the length of song required to be generated
len_gen_song = 600

# %% [markdown]
# ##Generation logic

# %% [markdown]
# ###Boost

# %%
# Use a random snippet as a seed for generating the new song.
bias = 60 #int(np.random.random()*25) + 20
GEN_SEED_RANDOMLY = True 
if GEN_SEED_RANDOMLY:
    ind = np.random.randint(NUM_SONGS)
else:
    ind = 297
    
gen_song = encoded_snippets[ind][:timesteps].tolist()

for i in range(len_gen_song):  
# boost
    if ( (np.array(gen_song[-100:]).sum() < np.array(encoded_snippets[ind][:timesteps].tolist()).sum() - 50)\
        & (len(gen_song[:-100]) >= 99) ):
        print('boost')
        ind = np.random.randint(NUM_SONGS)
        gen_song_boost = encoded_snippets[ind][:int(timesteps/4)].tolist()
        gen_song.extend(gen_song_boost)
# create seed
    # get the first 65 notes of seed
    seed_x = encoded_snippets[ind][:timesteps].tolist()[:bias]
    # get the remaining 35 from the previously generated snippet
    seed_new = gen_song[int(-timesteps+bias):]
    # append the two arrays
    seed_x.extend(seed_new)
    # convert to numpy array
    seed_x = np.array([seed_x])

# generate music!
    # input seed
    seed = {input_vec: seed_x}
    # generate new note
    pred_notes1 = sess.run(pred_notes, feed_dict = seed)
    # append notes to create song
    gen_song.append(np.array(pred_notes1[0]))

# print success %
    if ((i*100//len_gen_song == 25) & (i%10 == 0) ):
      print('25% complete')
    elif ((i*100//len_gen_song == 50) & (i%10 == 0) ):
      print('50% complete')
    elif ((i*100//len_gen_song == 75) & (i%10 == 0) ):
      print('75% complete')

print('100% complete')
# Out:
# 25% complete
# 50% complete
# 75% complete
# 100% complete

# %%
noteStateMatrixToMidi(gen_song[timesteps:], name = './' + song_name + '_' + str(ind) + '_' + str(bias))
print("saved generated song! seed ind : {} and bias : {}".format(ind, bias))
#Download the song from the files section on the left hand side panel (click on '>' button)
# Out:
# saved generated song! seed ind : 314 and bias : 90
